# %%
from pyson.utils import *

# %%
paths, labels, = load_db('../test_images/spe/dt_img/label.json')

# %%
for path, label in zip(paths, labels):
    path = path.replace('.txt', '')
    show(path)
    print(path, label, '\n', '-'*50)
# Out:
# ../test_images/spe/dt_img/33_ID1_Handwriting.png ['昭和 3年 12月 4 日']
#  --------------------------------------------------
# ../test_images/spe/dt_img/06_ID1_Handwriting.png ['平成 26 年 7月 27 日']
#  --------------------------------------------------
# ../test_images/spe/dt_img/23_ID1_Handwriting.png ['| 20年 11月30日']
#  --------------------------------------------------
# ../test_images/spe/dt_img/22_ID1_Handwriting.png ['平成 2年 6月 1日']
#  --------------------------------------------------
# ../test_images/spe/dt_img/25_ID1_Handwriting.png ['昭和60年6月 / 日']
#  --------------------------------------------------
# ../test_images/spe/dt_img/24_ID1_Handwriting.png ['平成)年/月/日・']
#  --------------------------------------------------
# ../test_images/spe/dt_img/02_ID1_Handwriting.png ['昭和50年11月jpg']
#  --------------------------------------------------
# ../test_images/spe/dt_img/34_ID1_Handwriting.png ['昭和。年\n', '月 4日']
#  --------------------------------------------------
# ...

# %%
# Out:
# '../test_images/spe/dt_img/33_ID1_Handwriting.txt.png'
